# %%
b=float(input("Ingrese la base: "))
h=float(input("Ingrese la altura: "))
a=(b*h)/2
print(a)
# Out:
# Ingrese la base: 4
# Ingrese la altura: 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-955929925.py in <cell line: 0>()
#       2 h=float(input("Ingrese la altura: "))
#       3 a=(b*h)/2
# ----> 4 print(a)
#
# TypeError: 'float' object is not callable

# %%
c = float(input("Ingrese grados Celsius: "))
f = (c * 9/5) + 32
print(f"{c}°C equivalen a {f}°F")
# Out:
# Ingrese grados Celsius: 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-924732626.py in <cell line: 0>()
#       1 c = float(input("Ingrese grados Celsius: "))
#       2 f = (c * 9/5) + 32
# ----> 3 print(f"{c}°C equivalen a {f}°F")
#
# TypeError: 'float' object is not callable

# %%
Num1=float(input("Ingrese el primer numero"))
Num2=float(input("Ingrese el segundo numero"))
Num3=float(input("Ingrese el tercero numero"))
prom=(Num1+Num2+Num3)/3

print(f"promedio es {prom}")

# %%
r=float(input("Ingrese el radio del circulo: "))
a=(3.14*r*r)
p=(2*3.14)*r

print(f"area es {a} y perimetro es {p}")
# Out:
# Ingrese el radio del circulo: 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3978598592.py in <cell line: 0>()
#       3 p=(2*3.14)*r
#       4
# ----> 5 print(f"area es {a} y perimetro es {p}")
#
# TypeError: 'float' object is not callable
