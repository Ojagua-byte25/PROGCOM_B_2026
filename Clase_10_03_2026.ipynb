# %% [markdown]
# <a href="https://colab.research.google.com/github/Ojagua-byte25/PROGCOM_B_2026/blob/main/Clase_10_03_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #WHILE
# 1. Cuando no se sabe cuántas veces se repite una acción.
# 2. Es gobernado por una condición de parada.
# 3. Es necesaria una condición inicial, la cual **DEBE** cambiar adentro del ciclo.
# Sintaxis
# ```
# While(condicion):
# codigo a repetir
# modificador de condición
# ```

# %%
# Suponer que la cantidad maxima de votantes son 10
# Suponer que son 5 candidatos
v1=0
v2=0
v3=0
v4=0
v5=0
vn=0
vb=0
persona=0
votico="s"
documentos_votados = []  # Almacena los IDs que ya votaron

while votico=="s" and persona<=10:
    id=input("Ingresa tu numero de documento: ")

    if id in documentos_votados:
        print(f"El documento {id} ya emitió su voto anteriormente.")
    else:
        documentos_votados.add(id)
        voto=input("Ingrese por quien quiere votar: \n1. Elefante blanco \n2. Pantera rosa \n3. Jotape Hernandez \n4. Paloma \n5. Quevedito \n6. Voto en blanco \n")
        if voto=="1": v1+=1
        elif voto=="2": v2+=1
        elif voto=="3": v3+=1
        elif voto=="4": v4+=1
        elif voto=="5": v5+=1
        elif voto=="6": vb+=1
        else: vn+=1
        print("Gracias por su voto")
        persona+=1

    votico=input("Hay personas antes de las 4:00PM? (s/n): ")
    print("")

print(f" RESULTADOS: \n1 Elefante blanco: {v1} \n2. Pantera rosa: {v2} \n3. Jotape Hernandez: {v3} \n4. Paloma: {v4} \n5. Quevedito: {v5} \n6. Voto en blanco {vb} \nVoto nulo: {vn}")

# %% [markdown]
# #LISTAS
# 1. Tienen index (numeración)
# 2. Son finitas
# 3. Son mutables
#
# Sintaxis
# ```
# #Forma canónica
# variables=[]
# #Extensión
# variable=[e,e1,e3,...;en]
# # Comprensión: fórmula que genera todos los elementos de la lista.
# ```

# %%
figura=["angelitos","estrella fugaz","dinosaurios","diablitos"]

# %% [markdown]
# ##Operaciones con listas
# Recorrer listas
# 1. Verificar elementos dentro de lista
# 2. Borrar elementos en la lista
# 3. Agregar elementos a la lista
# 4. Mutabilidad de las listas

# %% [markdown]
# 1.Recorrer listas

# %%
#len: Calcula el tamaño de un dato
for elemento in range(len(figura)):
  print(figura[elemento])
# Out:
# angelitos
# estrella fugaz
# dinosaurios
# diablitos

# %%
#len: Calcula el tamaño de un dato
for elemento in range(len(figura)):
  print(figura[elemento],":",cantidad[elemento])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_257/1465865716.py in <cell line: 0>()
#       1 #len: Calcula el tamaño de un dato
#       2 for elemento in range(len(figura)):
# ----> 3   print(figura[elemento],":",cantidad[elemento])
#
# NameError: name 'cantidad' is not defined

# %% [markdown]
# ###2. Verificar elementos dentro de la lista

# %%
user=input("Qué figura quiere comprar?")
for elemento in range(len(figura)):
 if user==figura[elemento]: print("si hay🍪")
 else: print("No hay😧")
# Out:
# Qué figura quiere comprar?dinosaurios
# No hay😧
# No hay😧
# si hay🍪
# No hay😧

# %%
if user in figura: print("si hay🍪")
else: print("No hay😧")
# Out:
# si hay🍪

# %%
print("Si hay🍪" if user in figura else "No hay😧")
# Out:
# Si hay🍪

# %%
figura
# Out:
# ['angelitos', 'estrella fugaz', 'dinosaurios', 'diablitos']

# %%
figura[3]="moñitos"
figura
# Out:
# ['angelitos', 'estrella fugaz', 'dinosaurios', 'moñitos']

# %%
#Para aumentar el tamaño de la lista
figura.append("dinosaurios")
figura
# Out:
# ['angelitos', 'estrella fugaz', 'dinosaurios', 'moñitos', 'dinosaurios']

# %% [markdown]
# ##Recorriendo listas

# %%
#Para ver los elementos del 1 al 3
figura[1:4]
# Out:
# ['estrella fugaz', 'dinosaurios', 'moñitos']

# %%
figura[-1]
# Out:
# 'dinosaurios'

# %%
figura[len(figura)-1]
# Out:
# 'dinosaurios'

# %%
#Imprima todo hasta la posición 3
figura[:3]
# Out:
# ['angelitos', 'estrella fugaz', 'dinosaurios']

# %%
#Imprima desde la posición 1 hasta el final
figura[1:]
# Out:
# ['estrella fugaz', 'dinosaurios', 'moñitos', 'dinosaurios']

# %%
figura[-3]
# Out:
# 'dinosaurios'

# %%
figura[-3:-1]
# Out:
# ['dinosaurios', 'moñitos']

# %% [markdown]
# ##Métodos de listas
# 1. Append. agregar un elemento a la lista. Aumentar el tamaño de la lista.**OJO**: Diferente a reescribir un elemento de la lista.
# 2. len: Calcula el tamaño de un dato.
# 3. Count: Cuenta cuantos elementos iguales hay en una lista.
# 4. Copy: copia los elementos de una lista.

# %%
len(figura)

# %%
figura.count("angelitos")

# %%
galletas.append("chocolate")
