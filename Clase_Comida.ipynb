# %% [markdown]
# <a href="https://colab.research.google.com/github/Ojagua-byte25/PROGCOM_B_2026/blob/main/Clase_Comida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Comida():
  #Constructor
  def _init_(self,carbohidrato,proteina,fruta,vegetal,bebida):
    self.carbohidrato=carbohidrato
    self.proteina=proteina
    self.fruta=fruta
    self.vegetal=vegetal
    self.bebida=bedida

  def elegir_comida(self,plato,cubiertos,servilleta,cant):
    desayuno=("proteina")

# %%
class Buffet:
  #Constructor
  def __init__(self, carbohidrato, proteina, fruta, vegetal, bebida):
    self.carbohidrato=carbohidrato
    self.proteina=proteina
    self.fruta=fruta
    self.vegetal=vegetal
    self.bebida=bebida

  def elegir_comida(self, plato, cubiertos, servilleta, cant):
    desayuno={"proteína":["huevo", "salchicha", "pollo", "carne"],
              "carbohidrato":["arepa","pancake", "pan"],
              "fruta":["banano","fresa", "mango", "uva"],
              "vegetal":["cebolla","aguacate","zanahoria"],
              "bebida":["gaseosas", "café", "chocolate"]}

    if self.proteina in desayuno["proteína"]:
      print(f"Meto la {self.proteina} en el plato")
    else:
      print("Elija otra proteina")

# %%
pedido1=Buffet("arepa", "salchicha", "fresa", "cebolla", "café")

# %%
pedido1.elegir_comida("si","si","si",2)
# Out:
# Meto la salchicha en el plato
