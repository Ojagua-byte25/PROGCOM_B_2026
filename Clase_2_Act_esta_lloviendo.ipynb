# %% [markdown]
# <a href="https://colab.research.google.com/github/Ojagua-byte25/PROGCOM_B_2026/blob/main/Clase_2_Act_esta_lloviendo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ESTRUCTURAS de selección
# Evalua comdiciones (su valor de verdad)
# 1.IF/ELSE
# 2.IF TERNARIO
# 3.IF/ELIF/ELSE
# 4.CASE

# %% [markdown]
# ##IF/ELSE
#
# Evalua una o mas condiciones,y dependiendo de su valor de verdard, realizara una accion u otra(solo dos acciones)
# Sintaxis

# %%
lluvia=input("Está lloviendo? ")
# Out:
# Está lloviendo? 4

# %%
if lluvia=="sí" or lluvia=="si" or lluvia=="sí. Muchisimo":
 print("Esta lloviendo, guarde la ropa. Utilice sombrilla")
else:
 print("Salga tranquilo, el dia esta piola")
# Out:
# Salga tranquilo, el dia esta piola

# %% [markdown]
# if ternario
#
# Sintaxis

# %% [markdown]
# variable= (código si condición es verdadera) if (condición) else

# %%
aguacero= "Esta lloviendo, guarde la ropa. Utilice sombrilla" if lluvia=="sí" else "Salga tranquilo, el dia esta piola"

# %%
if aguacero==2:
  print("Salga tranquilo")
else:
  cantidad=int(input("En qué porcentaje 0 - muy poco, >90, torrencial"))
  if cantidad>=0 and cantidad<30: print("Está serenando, lleve paraguas")
  elif cantidad>=30 and cantidad<70:
    print("Esta lloviendo, guarde la ropa. Utilice sombrilla")
  else:
    print("Hay tormenta, no salga de la casa")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3195587994.py in <cell line: 0>()
# ----> 1 if aguacero==2:
#       2   print("Salga tranquilo")
#       3 else:
#       4   cantidad=int(input("En qué porcentaje 0 - muy poco, >90, torrencial"))
#       5   if cantidad>=0 and cantidad<30: print("Está serenando, lleve paraguas")
#
# NameError: name 'aguacero' is not defined
